# %% [markdown]
# <a href="https://colab.research.google.com/github/yasashwiguggilla/class-9am/blob/main/yashu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('yashu')
# Out:
# yashu

# %%
a=10
b=6
print(a+b)
# Out:
# 16
